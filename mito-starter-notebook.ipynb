# %%
# Run this cell to render a mitosheet
# See mito's documentation here: https://docs.trymito.io/how-to/creating-a-mitosheet
# Join our Discord for support here: https://discord.gg/XdJSZyejJU

import mitosheet
mitosheet.sheet()
# Out:
# MitoWidget(analysis_data_json='{"analysisName": "UUID-0e19182d-13c1-44fa-b542-64805448bd99", "code": {"imports…

# %%
from mitosheet import *; register_analysis('UUID-fe16325e-3784-4560-8a6c-0d3291aaca2f')

# Imported /Users/sven-kristjanbormann/Downloads/mpg.csv
import pandas as pd
mpg_csv = pd.read_csv(r'/Users/sven-kristjanbormann/Downloads/mpg.csv')

# Pivoted mpg_csv into df2
mpg_csv_pivot = pd.DataFrame(data={})

# Imported /Users/sven-kristjanbormann/Downloads/germanyhigh-priority-incoming-view-2021-11-16-0907.csv
import pandas as pd
germanyhigh_priority_incoming_view_2021_11_16_0907_csv = pd.read_csv(r'/Users/sven-kristjanbormann/Downloads/germanyhigh-priority-incoming-view-2021-11-16-0907.csv')

# Imported /Users/sven-kristjanbormann/Downloads/HP-Scooters-Germany-w48.csv
import pandas as pd
HP_Scooters_Germany_w48_csv = pd.read_csv(r'/Users/sven-kristjanbormann/Downloads/HP-Scooters-Germany-w48.csv')

# Deleted dataframe mpg_csv_pivot
del mpg_csv_pivot

# Deleted dataframe germanyhigh_priority_incoming_view_2021_11_16_0907_csv
del germanyhigh_priority_incoming_view_2021_11_16_0907_csv

# Added column new-column-0y5k to HP_Scooters_Germany_w48_csv
HP_Scooters_Germany_w48_csv.insert(1, 'new-column-0y5k', 0)
